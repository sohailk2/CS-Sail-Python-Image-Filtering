# %% [markdown]
# # Pixels from Images

# %%
from PIL import Image
import numpy as np
import random

# %% [markdown]
# ### OPENING IMAGE FROM A FILE

# %%
cupcakeImage = Image.open("Images/cupcake.jpeg")

# %%
# now lets show the image
display(cupcakeImage)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=826x620 at 0x126FA7DBFD0>

# %% [markdown]
# ### Getting pixel values from this file

# %% [markdown]
# # Let's get into some steganography

# %% [markdown]
# ## First, we'll create the encoded image with the secret message

# %% [markdown]
# ### Read through and try and figure out what the next few cells do

# %%
messageImage = Image.open("Images/Secret.png")

# %%
display(messageImage)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2304x1296 at 0x126FECF17B8>

# %%
messageBitmap = np.array(messageImage)

for i in range(len(messageBitmap)):
    for j in range(len(messageBitmap[i])):
        flag = random.choice([True, False])
        
        pixel = messageBitmap[i][j]
        
        if not (pixel[0] == 127 and pixel[1] == 127 and pixel[2] == 127):
            if (flag):
                pixel[0] = 0
                pixel[1] = 0
                pixel[2] = 0
            else:
                pixel[0] = 255
                pixel[1] = 255
                pixel[2] = 255
        
result = Image.fromarray(messageBitmap)
display(result)
# Out:
# <PIL.Image.Image image mode=RGB size=2304x1296 at 0x126FFF4F710>
